1 MB 3.9 MB/s eta 0:00:03
#    ----------------------------- ---------- 20.4/28.1 MB 3.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 20.6/28.1 MB 3.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 20.8/28.1 MB 3.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 21.0/28.1 MB 3.9 MB/s eta 0:00:02
#    ------------------------------ --------- 21.2/28.1 MB 3.9 MB/s eta 0:00:02
#    ------------------------------ --------- 21.3/28.1 MB 3.9 MB/s eta 0:00:02
#    ------------------------------ --------- 21.5/28.1 MB 3.9 MB/s eta 0:00:02
#    ------------------------------ --------- 21.7/28.1 MB 3.9 MB/s eta 0:00:02
#    ------------------------------- -------- 21.9/28.1 MB 3.9 MB/s eta 0:00:02
#    ------------------------------- -------- 22.1/28.1 MB 3.9 MB/s eta 0:00:02
#    ------------------------------- -------- 22.3/28.1 MB 3.9 MB/s eta 0:00:02
#    ------------------------------- -------- 22.5/28.1 MB 3.9 MB/s eta 0:00:02
#    -------------------------------- ------- 22.6/28.1 MB 4.0 MB/s eta 0:00:02
#    -------------------------------- ------- 22.8/28.1 MB 3.9 MB/s eta 0:00:02
#    -------------------------------- ------- 23.0/28.1 MB 3.9 MB/s eta 0:00:02
#    --------------------------------- ------ 23.2/28.1 MB 3.9 MB/s eta 0:00:02
#    --------------------------------- ------ 23.4/28.1 MB 3.9 MB/s eta 0:00:02
#    --------------------------------- ------ 23.6/28.1 MB 3.9 MB/s eta 0:00:02
#    --------------------------------- ------ 23.7/28.1 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 23.9/28.1 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 24.1/28.1 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 24.3/28.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 24.5/28.1 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 24.6/28.1 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 24.8/28.1 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 25.0/28.1 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 25.2/28.1 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 25.3/28.1 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 25.3/28.1 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 25.3/28.1 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 25.8/28.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 25.9/28.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 26.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 26.3/28.1 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 26.5/28.1 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 26.7/28.1 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 26.9/28.1 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 27.1/28.1 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 27.3/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  27.5/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  27.6/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  27.8/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.0/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 28.1/28.1 MB 2.3 MB/s eta 0:00:00
# Installing collected packages: soxr, msgpack, llvmlite, lazy-loader, audioread, soundfile, pooch, numba, librosa
# Successfully installed audioread-3.0.1 lazy-loader-0.3 librosa-0.10.1 llvmlite-0.41.1 msgpack-1.0.7 numba-0.58.1 pooch-1.8.0 soundfile-0.12.1 soxr-0.3.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import librosa
import os

# %%
dataset_folder_path = 'AudioWAV'

# Function to extract MFCC features from audio files
def extract_features(file_path, mfcc=True, chroma=True, mel=True):
    with tf.device('/device:GPU:0'):  # Use GPU if available
        audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast')
        result = np.array([])
        if mfcc:
            mfccs = np.mean(librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40).T, axis=0)
            result = np.hstack((result, mfccs))
        if chroma:
            chroma = np.mean(librosa.feature.chroma_stft(y=audio, sr=sample_rate).T, axis=0)
            result = np.hstack((result, chroma))
        if mel:
            mel = np.mean(librosa.feature.melspectrogram(y=audio, sr=sample_rate).T, axis=0)
            result = np.hstack((result, mel))
    return result

# %%
#pip install resampy
# Out:
# Collecting resampy
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#       --------------------------------------- 0.1/3.1 MB 812.7 kB/s eta 0:00:04
#      -- ------------------------------------- 0.2/3.1 MB 1.6 MB/s eta 0:00:02
#      ----- ---------------------------------- 0.4/3.1 MB 2.3 MB/s eta 0:00:02
#      --------- ------------------------------ 0.7/3.1 MB 3.2 MB/s eta 0:00:01
#      ------------ --------------------------- 1.0/3.1 MB 3.7 MB/s eta 0:00:01
#      ---------------- ----------------------- 1.3/3.1 MB 4.0 MB/s eta 0:00:01
#      ------------------- -------------------- 1.5/3.1 MB 4.1 MB/s eta 0:00:01
#      --------------------- ------------------ 1.7/3.1 MB 4.1 MB/s eta 0:00:01
#      ------------------------ --------------- 1.9/3.1 MB 4.1 MB/s eta 0:00:01
#      -------------------------- ------------- 2.0/3.1 MB 4.1 MB/s eta 0:00:01
#      ----------------------------- ---------- 2.2/3.1 MB 4.1 MB/s eta 0:00:01
#      ------------------------------- -------- 2.4/3.1 MB 4.1 MB/s eta 0:00:01
#      --------------------------------- ------ 2.6/3.1 MB 4.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 2.7/3.1 MB 4.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 2.7/3.1 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------- 3.1/3.1 MB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from resampy) (1.24.2)
# Requirement already satisfied: numba>=0.53 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from resampy) (0.58.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from numba>=0.53->resampy) (0.41.1)
# Installing collected packages: resampy
# Successfully installed resampy-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
data = []
labels = []

for file in os.listdir(dataset_folder_path):
    if file.endswith('.wav') or file.endswith('.mp3'):  # Adjust file extensions as needed
        file_path = os.path.join(dataset_folder_path, file)
        feature = extract_features(file_path)
        data.append(feature)
        labels.append(file.split('_')[0])  # Assuming file names are in the format 'emotion_filename.wav'
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(

# %%
le = LabelEncoder()
labels = le.fit_transform(labels)

# Convert data and labels to numpy arrays
data = np.array(data)
labels = np.array(labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Normalize the data
X_train = (X_train - np.min(X_train)) / (np.max(X_train) - np.min(X_train))
X_test = (X_test - np.min(X_test)) / (np.max(X_test) - np.min(X_test))

# Reshape the data for input to a Convolutional Neural Network (CNN)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Convert labels to one-hot encoding
y_train = to_categorical(y_train, num_classes=len(le.classes_))
y_test = to_categorical(y_test, num_classes=len(le.classes_))

# %%
model = Sequential()
model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.25))
model.add(Conv1D(64, kernel_size=3, activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.25))
model.add(Conv1D(128, kernel_size=3, activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(len(le.classes_), activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20, batch_size=64)
# Out:
# Epoch 1/20
# 94/94 [==============================] - 8s 57ms/step - loss: 4.9725 - accuracy: 0.0225 - val_loss: 4.7015 - val_accuracy: 0.0114
# Epoch 2/20
# 94/94 [==============================] - 5s 51ms/step - loss: 4.2555 - accuracy: 0.0590 - val_loss: 6.2582 - val_accuracy: 0.0121
# Epoch 3/20
# 94/94 [==============================] - 5s 55ms/step - loss: 3.7852 - accuracy: 0.1147 - val_loss: 14.6309 - val_accuracy: 0.0128
# Epoch 4/20
# 94/94 [==============================] - 5s 54ms/step - loss: 3.4269 - accuracy: 0.1636 - val_loss: 44.5467 - val_accuracy: 0.0148
# Epoch 5/20
# 94/94 [==============================] - 5s 54ms/step - loss: 3.1117 - accuracy: 0.2232 - val_loss: 200.8214 - val_accuracy: 0.0128
# Epoch 6/20
# 94/94 [==============================] - 5s 55ms/step - loss: 2.8030 - accuracy: 0.2836 - val_loss: 496.1025 - val_accuracy: 0.0128
# Epoch 7/20
# 94/94 [==============================] - 5s 54ms/step - loss: 2.5124 - accuracy: 0.3430 - val_loss: 856.7654 - val_accuracy: 0.0128
# Epoch 8/20
# 94/94 [==============================] - 5s 53ms/step - loss: 2.2957 - accuracy: 0.3857 - val_loss: 1029.6829 - val_accuracy: 0.0128
# Epoch 9/20
# 94/94 [==============================] - 5s 52ms/step - loss: 2.1160 - accuracy: 0.4284 - val_loss: 1285.5651 - val_accuracy: 0.0161
# Epoch 10/20
# 94/94 [==============================] - 5s 53ms/step - loss: 1.9200 - accuracy: 0.4761 - val_loss: 1420.9325 - val_accuracy: 0.0161
# Epoch 11/20
# 94/94 [==============================] - 5s 54ms/step - loss: 1.7847 - accuracy: 0.5125 - val_loss: 1639.8234 - val_accuracy: 0.0161
# Epoch 12/20
# 94/94 [==============================] - 5s 56ms/step - loss: 1.6936 - accuracy: 0.5283 - val_loss: 1681.9003 - val_accuracy: 0.0161
# Epoch 13/20
# 94/94 [==============================] - 5s 53ms/step - loss: 1.5417 - accuracy: 0.5740 - val_loss: 1127.6501 - val_accuracy: 0.0107
# Epoch 14/20
# 94/94 [==============================] - 5s 53ms/step - loss: 1.4747 - accuracy: 0.5921 - val_loss: 912.2343 - val_accuracy: 0.0161
# Epoch 15/20
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3799 - accuracy: 0.6133 - val_loss: 906.7283 - val_accuracy: 0.0161
# Epoch 16/20
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3178 - accuracy: 0.6303 - val_loss: 1063.6211 - val_accuracy: 0.0161
# Epoch 17/20
# 94/94 [==============================] - 5s 52ms/step - loss: 1.2585 - accuracy: 0.6417 - val_loss: 848.4795 - val_accuracy: 0.0134
# Epoch 18/20
# 94/94 [==============================] - 5s 54ms/step - loss: 1.2142 - accuracy: 0.6511 - val_loss: 834.5051 - val_accuracy: 0.0134
# Epoch 19/20
# 94/94 [==============================] - 5s 52ms/step - loss: 1.1440 - accuracy: 0.6711 - val_loss: 1368.5614 - val_accuracy: 0.0134
# Epoch 20/20
# 94/94 [==============================] - 5s 50ms/step - loss: 1.1218 - accuracy: 0.6716 - val_loss: 1383.2437 - val_accuracy: 0.0134

# %%
accuracy = model.evaluate(X_test, y_test)[1]
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 47/47 [==============================] - 0s 6ms/step - loss: 1383.2438 - accuracy: 0.0134
# Test Accuracy: 1.34%

# %%
model.save('voice_analysis_model.h5')
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model_json = model.to_json()
with open("voice.json","w") as json_file:
    json_file.write(model_json)
